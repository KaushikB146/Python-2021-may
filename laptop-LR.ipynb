# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
pd.pandas.set_option('display.max_columns',None)

# %%
df = pd.read_csv('laptops.csv', encoding='latin-1')

# %%
df
# Out:
#       Unnamed: 0 Company                                    Product  \
# 0              1   Apple                                MacBook Pro
# 1              2   Apple                                Macbook Air
# 2              3      HP                                     250 G6
# 3              4   Apple                                MacBook Pro
# 4              5   Apple                                MacBook Pro
# 5              6    Acer                                   Aspire 3
# 6              7   Apple                                MacBook Pro
# 7              8   Apple                                Macbook Air
# 8              9    Asus                            ZenBook UX430UN
# 9             10    Acer                                    Swift 3
# 10            11      HP                                     250 G6
# 11            12      HP                                     250 G6
# 12            13   Apple                                MacBook Pro
# 13            14    Dell                              Inspiron 3567
# 14            15   Apple                                MacBook 12"
# 15            16   Apple                                MacBook Pro
# 16            17    Dell                              Inspiron 3567
# 17            18   Apple                                MacBook Pro
# 18            19  Lenovo                          IdeaPad 320-15IKB
# 19            20    Dell                                     XPS 13
# 20            21    Asus                            Vivobook E200HA
# 21            22  Lenovo                         Legion Y520-15IKBN
# 22            23      HP                                     255 G6
# 23            24    Dell                              Inspiron 5379
# 24            25      HP    15-BS101nv (i7-8550U/8GB/256GB/FHD/W10)
# 25            26    Dell                              Inspiron 3567
# 26            27   Apple                                MacBook Air
# 27            28    Dell                              Inspiron 5570
# 28            29    Dell                              Latitude 5590
# 29            30      HP                                ProBook 470
# ...          ...     ...                                        ...
# 1273        1291      HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1274        1292    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)
# 1275        1293    Asus                       ZenBook UX305CA-UBM1
# 1276        1294    Dell                              Inspiron 3567
# 1277        1295    Acer                             Aspire ES1-531
# 1278        1296    Dell                              Inspiron 3552
# 1279        1297  Lenovo                         IdeaPad Y700-15ISK
# 1280        1298      HP                        Pavilion 15-AW003nv
# 1281        1299    Dell                              Inspiron 3567
# 1282        1300      HP                           Stream 11-Y000na
# 1283        1301    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# 1284        1302  Lenovo                             Yoga 500-14ISK
# 1285        1303  Lenovo                             Yoga 900-13ISK
# 1286        1304  Lenovo                         IdeaPad 100S-14IBR
# 1287        1305      HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1288        1306    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)
# 1289        1307    Asus                       ZenBook UX305CA-UBM1
# 1290        1308    Dell                              Inspiron 3567
# 1291        1309    Acer                             Aspire ES1-531
# 1292        1310    Dell                              Inspiron 3552
# 1293        1311  Lenovo                         IdeaPad Y700-15ISK
# 1294        1312      HP                        Pavilion 15-AW003nv
# 1295        1313    Dell                              Inspiron 3567
# 1296        1314      HP                           Stream 11-Y000na
# 1297        1315    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# 1298        1316  Lenovo                             Yoga 500-14ISK
# 1299        1317  Lenovo                             Yoga 900-13ISK
# 1300        1318  Lenovo                         IdeaPad 100S-14IBR
# 1301        1319      HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302        1320    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# 1              Ultrabook    13.3                                    1440x900
# 2               Notebook    15.6                           Full HD 1920x1080
# 3              Ultrabook    15.4          IPS Panel Retina Display 2880x1800
# 4              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# 5               Notebook    15.6                                    1366x768
# 6              Ultrabook    15.4          IPS Panel Retina Display 2880x1800
# 7              Ultrabook    13.3                                    1440x900
# 8              Ultrabook    14.0                           Full HD 1920x1080
# 9              Ultrabook    14.0                 IPS Panel Full HD 1920x1080
# 10              Notebook    15.6                                    1366x768
# 11              Notebook    15.6                           Full HD 1920x1080
# 12             Ultrabook    15.4          IPS Panel Retina Display 2880x1800
# 13              Notebook    15.6                           Full HD 1920x1080
# 14             Ultrabook    12.0          IPS Panel Retina Display 2304x1440
# 15             Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# 16              Notebook    15.6                           Full HD 1920x1080
# 17             Ultrabook    15.4          IPS Panel Retina Display 2880x1800
# 18              Notebook    15.6                           Full HD 1920x1080
# 19             Ultrabook    13.3   IPS Panel Full HD / Touchscreen 1920x1080
# 20               Netbook    11.6                                    1366x768
# 21                Gaming    15.6                 IPS Panel Full HD 1920x1080
# 22              Notebook    15.6                                    1366x768
# 23    2 in 1 Convertible    13.3             Full HD / Touchscreen 1920x1080
# 24             Ultrabook    15.6                           Full HD 1920x1080
# 25              Notebook    15.6                                    1366x768
# 26             Ultrabook    13.3                                    1440x900
# 27              Notebook    15.6                           Full HD 1920x1080
# 28             Ultrabook    15.6                           Full HD 1920x1080
# 29              Notebook    17.3                           Full HD 1920x1080
# ...                  ...     ...                                         ...
# 1273            Notebook    15.6                                    1366x768
# 1274            Notebook    15.6                                    1366x768
# 1275           Ultrabook    13.3                 IPS Panel Full HD 1920x1080
# 1276            Notebook    15.6                                    1366x768
# 1277            Notebook    15.6                                    1366x768
# 1278            Notebook    15.6                                    1366x768
# 1279            Notebook    15.6                 IPS Panel Full HD 1920x1080
# 1280            Notebook    15.6                           Full HD 1920x1080
# 1281            Notebook    15.6                                    1366x768
# 1282             Netbook    11.6                                    1366x768
# 1283            Notebook    15.6                                    1366x768
# 1284  2 in 1 Convertible    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1285  2 in 1 Convertible    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1286            Notebook    14.0                                    1366x768
# 1287            Notebook    15.6                                    1366x768
# 1288            Notebook    15.6                                    1366x768
# 1289           Ultrabook    13.3                 IPS Panel Full HD 1920x1080
# 1290            Notebook    15.6                                    1366x768
# 1291            Notebook    15.6                                    1366x768
# 1292            Notebook    15.6                                    1366x768
# 1293            Notebook    15.6                 IPS Panel Full HD 1920x1080
# 1294            Notebook    15.6                           Full HD 1920x1080
# 1295            Notebook    15.6                                    1366x768
# 1296             Netbook    11.6                                    1366x768
# 1297            Notebook    15.6                                    1366x768
# 1298  2 in 1 Convertible    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  2 in 1 Convertible    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300            Notebook    14.0                                    1366x768
# 1301            Notebook    15.6                                    1366x768
# 1302            Notebook    15.6                                    1366x768
#
#                                        Cpu   Ram                  Memory  \
# 0                     Intel Core i5 2.3GHz   8GB               128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB     128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB               256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB               512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB               256GB SSD
# 5                  AMD A9-Series 9420 3GHz   4GB               500GB HDD
# 6                     Intel Core i7 2.2GHz  16GB     256GB Flash Storage
# 7                     Intel Core i5 1.8GHz   8GB     256GB Flash Storage
# 8               Intel Core i7 8550U 1.8GHz  16GB               512GB SSD
# 9               Intel Core i5 8250U 1.6GHz   8GB               256GB SSD
# 10              Intel Core i5 7200U 2.5GHz   4GB               500GB HDD
# 11                Intel Core i3 6006U 2GHz   4GB               500GB HDD
# 12                    Intel Core i7 2.8GHz  16GB               256GB SSD
# 13                Intel Core i3 6006U 2GHz   4GB               256GB SSD
# 14                  Intel Core M m3 1.2GHz   8GB               256GB SSD
# 15                    Intel Core i5 2.3GHz   8GB               256GB SSD
# 16              Intel Core i7 7500U 2.7GHz   8GB               256GB SSD
# 17                    Intel Core i7 2.9GHz  16GB               512GB SSD
# 18              Intel Core i3 7100U 2.4GHz   8GB                 1TB HDD
# 19              Intel Core i5 8250U 1.6GHz   8GB               128GB SSD
# 20             Intel Atom x5-Z8350 1.44GHz   2GB      32GB Flash Storage
# 21             Intel Core i5 7300HQ 2.5GHz   8GB    128GB SSD +  1TB HDD
# 22            AMD E-Series E2-9000e 1.5GHz   4GB               500GB HDD
# 23              Intel Core i5 8250U 1.6GHz   8GB               256GB SSD
# 24              Intel Core i7 8550U 1.8GHz   8GB               256GB SSD
# 25                Intel Core i3 6006U 2GHz   4GB                 1TB HDD
# 26                    Intel Core i5 1.6GHz   8GB     128GB Flash Storage
# 27              Intel Core i5 8250U 1.6GHz   8GB               256GB SSD
# 28              Intel Core i7 8650U 1.9GHz   8GB  256GB SSD +  256GB SSD
# 29              Intel Core i5 8250U 1.6GHz   8GB                 1TB HDD
# ...                                    ...   ...                     ...
# 1273            Intel Core i7 6500U 2.5GHz   6GB                 1TB HDD
# 1274  Intel Celeron Dual Core N3050 1.6GHz   4GB               500GB HDD
# 1275              Intel Core M 6Y30 0.9GHz   8GB               512GB SSD
# 1276            Intel Core i3 7100U 2.4GHz   6GB                 1TB HDD
# 1277  Intel Celeron Dual Core N3060 1.6GHz   4GB               500GB HDD
# 1278  Intel Celeron Dual Core N3050 1.6GHz   2GB               500GB HDD
# 1279           Intel Core i7 6700HQ 2.6GHz   8GB                 1TB HDD
# 1280             AMD A9-Series 9410 2.9GHz   6GB            1.0TB Hybrid
# 1281            Intel Core i7 7500U 2.7GHz   8GB                 1TB HDD
# 1282  Intel Celeron Dual Core N3060 1.6GHz   2GB      32GB Flash Storage
# 1283            Intel Core i7 6500U 2.5GHz   4GB               500GB HDD
# 1284            Intel Core i7 6500U 2.5GHz   4GB               128GB SSD
# 1285            Intel Core i7 6500U 2.5GHz  16GB               512GB SSD
# 1286  Intel Celeron Dual Core N3050 1.6GHz   2GB      64GB Flash Storage
# 1287            Intel Core i7 6500U 2.5GHz   6GB                 1TB HDD
# 1288  Intel Celeron Dual Core N3050 1.6GHz   4GB               500GB HDD
# 1289              Intel Core M 6Y30 0.9GHz   8GB               512GB SSD
# 1290            Intel Core i3 7100U 2.4GHz   6GB                 1TB HDD
# 1291  Intel Celeron Dual Core N3060 1.6GHz   4GB               500GB HDD
# 1292  Intel Celeron Dual Core N3050 1.6GHz   2GB               500GB HDD
# 1293           Intel Core i7 6700HQ 2.6GHz   8GB                 1TB HDD
# 1294             AMD A9-Series 9410 2.9GHz   6GB            1.0TB Hybrid
# 1295            Intel Core i7 7500U 2.7GHz   8GB                 1TB HDD
# 1296  Intel Celeron Dual Core N3060 1.6GHz   2GB      32GB Flash Storage
# 1297            Intel Core i7 6500U 2.5GHz   4GB               500GB HDD
# 1298            Intel Core i7 6500U 2.5GHz   4GB               128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB               512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB      64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB                 1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB               500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00
# 3               AMD Radeon Pro 455       macOS  1.83kg      2537.45
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60
# 5                    AMD Radeon R5  Windows 10   2.1kg       400.00
# 6          Intel Iris Pro Graphics    Mac OS X  2.04kg      2139.97
# 7           Intel HD Graphics 6000       macOS  1.34kg      1158.70
# 8             Nvidia GeForce MX150  Windows 10   1.3kg      1495.00
# 9           Intel UHD Graphics 620  Windows 10   1.6kg       770.00
# 10           Intel HD Graphics 620       No OS  1.86kg       393.90
# 11           Intel HD Graphics 520       No OS  1.86kg       344.99
# 12              AMD Radeon Pro 555       macOS  1.83kg      2439.97
# 13              AMD Radeon R5 M430  Windows 10   2.2kg       498.90
# 14           Intel HD Graphics 615       macOS  0.92kg      1262.40
# 15    Intel Iris Plus Graphics 640       macOS  1.37kg      1518.55
# 16              AMD Radeon R5 M430  Windows 10   2.2kg       745.00
# 17              AMD Radeon Pro 560       macOS  1.83kg      2858.00
# 18            Nvidia GeForce 940MX       No OS   2.2kg       499.00
# 19          Intel UHD Graphics 620  Windows 10  1.22kg       979.00
# 20           Intel HD Graphics 400  Windows 10  0.98kg       191.90
# 21         Nvidia GeForce GTX 1050  Windows 10   2.5kg       999.00
# 22                   AMD Radeon R2       No OS  1.86kg       258.00
# 23          Intel UHD Graphics 620  Windows 10  1.62kg       819.00
# 24           Intel HD Graphics 620  Windows 10  1.91kg       659.00
# 25           Intel HD Graphics 520  Windows 10   2.3kg       418.64
# 26          Intel HD Graphics 6000    Mac OS X  1.35kg      1099.00
# 27                  AMD Radeon 530  Windows 10   2.2kg       800.00
# 28          Intel UHD Graphics 620  Windows 10  1.88kg      1298.00
# 29            Nvidia GeForce 930MX  Windows 10   2.5kg       896.00
# ...                            ...         ...     ...          ...
# 1273            AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1274             Intel HD Graphics  Windows 10   2.2kg       369.00
# 1275         Intel HD Graphics 515  Windows 10   1.2kg       729.00
# 1276         Intel HD Graphics 620  Windows 10   2.3kg       459.00
# 1277         Intel HD Graphics 400       Linux   2.4kg       289.00
# 1278             Intel HD Graphics  Windows 10  2.20kg       379.00
# 1279       Nvidia GeForce GTX 960M  Windows 10   2.6kg       899.00
# 1280            AMD Radeon R7 M440  Windows 10  2.04kg       549.99
# 1281            AMD Radeon R5 M430       Linux   2.3kg       805.99
# 1282         Intel HD Graphics 400  Windows 10  1.17kg       209.00
# 1283           Nvidia GeForce 920M  Windows 10   2.2kg       720.32
# 1284         Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1285         Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1286             Intel HD Graphics  Windows 10   1.5kg       229.00
# 1287            AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1288             Intel HD Graphics  Windows 10   2.2kg       369.00
# 1289         Intel HD Graphics 515  Windows 10   1.2kg       729.00
# 1290         Intel HD Graphics 620  Windows 10   2.3kg       459.00
# 1291         Intel HD Graphics 400       Linux   2.4kg       289.00
# 1292             Intel HD Graphics  Windows 10  2.20kg       379.00
# 1293       Nvidia GeForce GTX 960M  Windows 10   2.6kg       899.00
# 1294            AMD Radeon R7 M440  Windows 10  2.04kg       549.99
# 1295            AMD Radeon R5 M430       Linux   2.3kg       805.99
# 1296         Intel HD Graphics 400  Windows 10  1.17kg       209.00
# 1297           Nvidia GeForce 920M  Windows 10   2.2kg       720.32
# 1298         Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1299         Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1300             Intel HD Graphics  Windows 10   1.5kg       229.00
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1302             Intel HD Graphics  Windows 10   2.2kg       369.00
#
# [1303 rows x 13 columns]

# %%
df.head()
# Out:
#    Unnamed: 0 Company      Product   TypeName  Inches  \
# 0           1   Apple  MacBook Pro  Ultrabook    13.3
# 1           2   Apple  Macbook Air  Ultrabook    13.3
# 2           3      HP       250 G6   Notebook    15.6
# 3           4   Apple  MacBook Pro  Ultrabook    15.4
# 4           5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros
# 0      1339.69
# 1       898.94
# 2       575.00
# 3      2537.45
# 4      1803.60

# %%
df.tail()
# Out:
#       Unnamed: 0 Company                              Product  \
# 1298        1316  Lenovo                       Yoga 500-14ISK
# 1299        1317  Lenovo                       Yoga 900-13ISK
# 1300        1318  Lenovo                   IdeaPad 100S-14IBR
# 1301        1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302        1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 1298  2 in 1 Convertible    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  2 in 1 Convertible    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300            Notebook    14.0                                    1366x768
# 1301            Notebook    15.6                                    1366x768
# 1302            Notebook    15.6                                    1366x768
#
#                                        Cpu   Ram              Memory  \
# 1298            Intel Core i7 6500U 2.5GHz   4GB           128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB           512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB  64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB             1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB           500GB HDD
#
#                         Gpu       OpSys  Weight  Price_euros
# 1298  Intel HD Graphics 520  Windows 10   1.8kg        638.0
# 1299  Intel HD Graphics 520  Windows 10   1.3kg       1499.0
# 1300      Intel HD Graphics  Windows 10   1.5kg        229.0
# 1301     AMD Radeon R5 M330  Windows 10  2.19kg        764.0
# 1302      Intel HD Graphics  Windows 10   2.2kg        369.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
# Unnamed: 0          1303 non-null int64
# Company             1303 non-null object
# Product             1303 non-null object
# TypeName            1303 non-null object
# Inches              1303 non-null float64
# ScreenResolution    1303 non-null object
# Cpu                 1303 non-null object
# Ram                 1303 non-null object
# Memory              1303 non-null object
# Gpu                 1303 non-null object
# OpSys               1303 non-null object
# Weight              1303 non-null object
# Price_euros         1303 non-null float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.4+ KB

# %%
df.describe()
# Out:
#         Unnamed: 0       Inches  Price_euros
# count  1303.000000  1303.000000  1303.000000
# mean    660.155794    15.017191  1123.686992
# std     381.172104     1.426304   699.009043
# min       1.000000    10.100000   174.000000
# 25%     331.500000    14.000000   599.000000
# 50%     659.000000    15.600000   977.000000
# 75%     990.500000    15.600000  1487.880000
# max    1320.000000    18.400000  6099.000000

# %%
df.describe(include='all')
# Out:
#          Unnamed: 0 Company Product  TypeName       Inches   ScreenResolution  \
# count   1303.000000    1303    1303      1303  1303.000000               1303
# unique          NaN      19     618         6          NaN                 40
# top             NaN  Lenovo  XPS 13  Notebook          NaN  Full HD 1920x1080
# freq            NaN     297      30       727          NaN                507
# mean     660.155794     NaN     NaN       NaN    15.017191                NaN
# std      381.172104     NaN     NaN       NaN     1.426304                NaN
# min        1.000000     NaN     NaN       NaN    10.100000                NaN
# 25%      331.500000     NaN     NaN       NaN    14.000000                NaN
# 50%      659.000000     NaN     NaN       NaN    15.600000                NaN
# 75%      990.500000     NaN     NaN       NaN    15.600000                NaN
# max     1320.000000     NaN     NaN       NaN    18.400000                NaN
#
#                                Cpu   Ram     Memory                    Gpu  \
# count                         1303  1303       1303                   1303
# unique                         118     9         39                    110
# top     Intel Core i5 7200U 2.5GHz   8GB  256GB SSD  Intel HD Graphics 620
# freq                           190   619        412                    281
# mean                           NaN   NaN        NaN                    NaN
# std                            NaN   NaN        NaN                    NaN
# min                            NaN   NaN        NaN                    NaN
# 25%                            NaN   NaN        NaN                    NaN
# 50%                            NaN   NaN        NaN                    NaN
# 75%                            NaN   NaN        NaN                    NaN
# max                            NaN   NaN        NaN                    NaN
#
#              OpSys Weight  Price_euros
# count         1303   1303  1303.000000
# unique           9    179          NaN
# top     Windows 10  2.2kg          NaN
# freq          1072    121          NaN
# mean           NaN    NaN  1123.686992
# std            NaN    NaN   699.009043
# min            NaN    NaN   174.000000
# 25%            NaN    NaN   599.000000
# 50%            NaN    NaN   977.000000
# 75%            NaN    NaN  1487.880000
# max            NaN    NaN  6099.000000

# %%
print(df.shape)
# Out:
# (1303, 13)

# %%
#droping User ID column as it is not an important feature
df.drop('Unnamed: 0',axis =1,inplace = True)

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69
# 1        Intel HD Graphics 6000  macOS  1.34kg       898.94
# 2         Intel HD Graphics 620  No OS  1.86kg       575.00
# 3            AMD Radeon Pro 455  macOS  1.83kg      2537.45
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg      1803.60

# %%
df.isnull().sum()
# Out:
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %% [markdown]
# no null values

# %% [markdown]
# EDA

# %%
sns.distplot(df['Price_euros'])

# %%
df['Company'].value_counts().plot(kind='bar')

# %%
sns.barplot(x=df['Company'],y=df['Price_euros'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['TypeName'].value_counts().plot(kind='bar')

# %%
sns.barplot(x=df['TypeName'],y=df['Price_euros'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Inches'].value_counts()
# Out:
# 15.6    665
# 14.0    197
# 13.3    164
# 17.3    164
# 12.5     39
# 11.6     33
# 13.9      6
# 13.5      6
# 12.0      6
# 12.3      5
# 15.4      4
# 10.1      4
# 15.0      4
# 13.0      2
# 18.4      1
# 14.1      1
# 17.0      1
# 11.3      1
# Name: Inches, dtype: int64

# %%
sns.distplot(df['Inches'])

# %%
df['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2256x1504                              6
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Retina Display 2880x1800                 4
# IPS Panel 2560x1440                                4
# IPS Panel Touchscreen 1920x1200                    4
# 1440x900                                           4
# Touchscreen 2400x1600                              3
# 2560x1440                                          3
# 1920x1080                                          3
# IPS Panel Touchscreen 1366x768                     3
# IPS Panel Quad HD+ 2560x1440                       3
# Quad HD+ 3200x1800                                 3
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Quad HD+ 3200x1800                       2
# IPS Panel Full HD 2160x1440                        2
# IPS Panel Retina Display 2736x1824                 1
# Touchscreen / Quad HD+ 3200x1800                   1
# Touchscreen / Full HD 1920x1080                    1
# IPS Panel Touchscreen 2400x1600                    1
# IPS Panel Full HD 1366x768                         1
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1920x1200                        1
# Touchscreen / 4K Ultra HD 3840x2160                1
# Name: ScreenResolution, dtype: int64

# %%
df['Touchscreen'] = df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)
df.sample(5)
# Out:
#      Company            Product            TypeName  Inches  \
# 701   Lenovo  IdeaPad 320-15AST            Notebook    15.6
# 1136      HP           ZBook 17         Workstation    17.3
# 1071      HP        ProBook 650            Notebook    15.6
# 1013      HP      EliteBook 840           Ultrabook    14.0
# 953     Asus    Chromebook Flip  2 in 1 Convertible    12.5
#
#                  ScreenResolution                          Cpu  Ram  \
# 701             Full HD 1920x1080    AMD A9-Series 9420 2.9GHz  4GB
# 1136  IPS Panel Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz  8GB
# 1071                     1366x768   Intel Core i5 6200U 2.3GHz  4GB
# 1013            Full HD 1920x1080   Intel Core i7 6500U 2.5GHz  8GB
# 953             Full HD 1920x1080  Intel Core M M7-6Y75 1.2GHz  8GB
#
#                   Memory                    Gpu       OpSys  Weight  \
# 701            256GB SSD         AMD Radeon 530  Windows 10   2.2kg
# 1136           256GB SSD   Nvidia Quadro M3000M   Windows 7     3kg
# 1071           500GB HDD  Intel HD Graphics 520  Windows 10  2.31kg
# 1013           256GB SSD  Intel HD Graphics 520  Windows 10  1.54kg
# 953   64GB Flash Storage  Intel HD Graphics 515   Chrome OS   1.2kg
#
#       Price_euros  Touchscreen
# 701        399.00            0
# 1136      3949.40            0
# 1071      1199.00            0
# 1013      1887.21            0
# 953       1159.00            0

# %%
df['Touchscreen'].value_counts().plot(kind='bar')

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price_euros'])

# %%
df['Ips'] = df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)
df.sample(5)
# Out:
#     Company             Product  TypeName  Inches  \
# 969  Lenovo   IdeaPad 310-15IKB  Notebook    15.6
# 581    Dell       Latitude 5580  Notebook    15.6
# 490  Lenovo       Thinkpad E570  Notebook    15.6
# 855    Dell       Latitude 5580  Notebook    15.6
# 301    Asus  Rog GL702VS-GC095T    Gaming    17.3
#
#                 ScreenResolution                          Cpu   Ram  \
# 969            Full HD 1920x1080   Intel Core i5 7200U 2.5GHz   6GB
# 581                     1366x768   Intel Core i5 7300U 2.6GHz   8GB
# 490  IPS Panel Full HD 1920x1080   Intel Core i5 7200U 2.5GHz   8GB
# 855            Full HD 1920x1080   Intel Core i5 7200U 2.5GHz   8GB
# 301            Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz  16GB
#
#                    Memory                      Gpu       OpSys Weight  \
# 969             256GB SSD     Nvidia GeForce 920MX  Windows 10  2.4kg
# 581             500GB HDD    Intel HD Graphics 620  Windows 10  1.9kg
# 490             256GB SSD     Nvidia GeForce 940MX  Windows 10  2.3kg
# 855             128GB SSD    Intel HD Graphics 620  Windows 10  1.9kg
# 301  256GB SSD +  1TB HDD  Nvidia GeForce GTX 1070  Windows 10  2.9kg
#
#      Price_euros  Touchscreen  Ips
# 969       695.00            0    0
# 581      1008.52            0    0
# 490      1011.99            0    1
# 855       945.00            0    0
# 301      2122.00            0    0

# %%
df['Ips'].value_counts().plot(kind='bar')

# %%
sns.barplot(x=df['Ips'],y=df['Price_euros'])

# %%
new = df['ScreenResolution'].str.split('x',n=1,expand=True)
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros  Touchscreen  Ips
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69            0    1
# 1        Intel HD Graphics 6000  macOS  1.34kg       898.94            0    0
# 2         Intel HD Graphics 620  No OS  1.86kg       575.00            0    0
# 3            AMD Radeon Pro 455  macOS  1.83kg      2537.45            0    1
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg      1803.60            0    1

# %%
df['X_sr'] = new[0]
df['Y_sr'] = new[1]

# %%
df.sample(5)
# Out:
#      Company                            Product            TypeName  Inches  \
# 470       HP                       Spectre x360  2 in 1 Convertible    13.3
# 615     Asus  FX753VD-GC007T (i7-7700HQ/8GB/1TB              Gaming    17.3
# 388     Dell                     Precision 5520         Workstation    15.6
# 785      MSI                         GS43VR 7RE              Gaming    14.0
# 1149  Lenovo                        ThinkPad X1  2 in 1 Convertible    14.0
#
#                                    ScreenResolution  \
# 470   IPS Panel 4K Ultra HD / Touchscreen 3840x2160
# 615                               Full HD 1920x1080
# 388                     IPS Panel Full HD 1920x1080
# 785                     IPS Panel Full HD 1920x1080
# 1149                IPS Panel Touchscreen 2560x1440
#
#                               Cpu   Ram                Memory  \
# 470    Intel Core i7 8550U 1.8GHz   8GB             512GB SSD
# 615   Intel Core i7 7700HQ 2.8GHz   8GB  128GB SSD +  1TB HDD
# 388   Intel Core i7 6820HQ 2.7GHz   8GB             256GB SSD
# 785   Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 1149   Intel Core i7 6500U 2.5GHz   8GB             256GB SSD
#
#                           Gpu       OpSys  Weight  Price_euros  Touchscreen  \
# 470    Intel UHD Graphics 620  Windows 10  1.29kg       1999.0            1
# 615   Nvidia GeForce GTX 1050  Windows 10     3kg       1168.0            0
# 388       Nvidia Quadro M1200  Windows 10     2kg       2135.0            0
# 785   Nvidia GeForce GTX 1060  Windows 10   1.6kg       1891.0            0
# 1149    Intel HD Graphics 520  Windows 10  1.27kg       2339.0            1
#
#       Ips                                      X_sr  Y_sr
# 470     1  IPS Panel 4K Ultra HD / Touchscreen 3840  2160
# 615     0                              Full HD 1920  1080
# 388     1                    IPS Panel Full HD 1920  1080
# 785     1                    IPS Panel Full HD 1920  1080
# 1149    1                IPS Panel Touchscreen 2560  1440

# %%
df['X_sr'] = df['X_sr'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])
df.head()
# Out:
#   Company      Product   TypeName  Inches                    ScreenResolution  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69            0    1
# 1        Intel HD Graphics 6000  macOS  1.34kg       898.94            0    0
# 2         Intel HD Graphics 620  No OS  1.86kg       575.00            0    0
# 3            AMD Radeon Pro 455  macOS  1.83kg      2537.45            0    1
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg      1803.60            0    1
#
#    X_sr  Y_sr
# 0  2560  1600
# 1  1440   900
# 2  1920  1080
# 3  2880  1800
# 4  2560  1600

# %%
df['X_sr'] = df['X_sr'].astype('int')
df['Y_sr'] = df['Y_sr'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 16 columns):
# Company             1303 non-null object
# Product             1303 non-null object
# TypeName            1303 non-null object
# Inches              1303 non-null float64
# ScreenResolution    1303 non-null object
# Cpu                 1303 non-null object
# Ram                 1303 non-null object
# Memory              1303 non-null object
# Gpu                 1303 non-null object
# OpSys               1303 non-null object
# Weight              1303 non-null object
# Price_euros         1303 non-null float64
# Touchscreen         1303 non-null int64
# Ips                 1303 non-null int64
# X_sr                1303 non-null int32
# Y_sr                1303 non-null int32
# dtypes: float64(2), int32(2), int64(2), object(10)
# memory usage: 152.8+ KB

# %%
#droping ScreenResolution column 
df.drop('ScreenResolution',axis =1,inplace = True)

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                         Cpu   Ram  \
# 0   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 2.3GHz   8GB
# 1   Apple  Macbook Air  Ultrabook    13.3        Intel Core i5 1.8GHz   8GB
# 2      HP       250 G6   Notebook    15.6  Intel Core i5 7200U 2.5GHz   8GB
# 3   Apple  MacBook Pro  Ultrabook    15.4        Intel Core i7 2.7GHz  16GB
# 4   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros  Touchscreen  Ips  X_sr  Y_sr
# 0      1339.69            0    1  2560  1600
# 1       898.94            0    0  1440   900
# 2       575.00            0    0  1920  1080
# 3      2537.45            0    1  2880  1800
# 4      1803.60            0    1  2560  1600

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz               190
# Intel Core i7 7700HQ 2.8GHz              146
# Intel Core i7 7500U 2.7GHz               134
# Intel Core i7 8550U 1.8GHz                73
# Intel Core i5 8250U 1.6GHz                72
# Intel Core i5 6200U 2.3GHz                68
# Intel Core i3 6006U 2GHz                  64
# Intel Core i7 6500U 2.5GHz                49
# Intel Core i7 6700HQ 2.6GHz               43
# Intel Core i3 7100U 2.4GHz                37
# Intel Core i5 7300HQ 2.5GHz               33
# Intel Celeron Dual Core N3350 1.1GHz      30
# Intel Celeron Dual Core N3060 1.6GHz      28
# Intel Core i7 6600U 2.6GHz                18
# Intel Core i3 6006U 2.0GHz                16
# Intel Core i5 7300U 2.6GHz                14
# Intel Pentium Quad Core N4200 1.1GHz      14
# Intel Core i7 7600U 2.8GHz                13
# Intel Core i5 6300U 2.4GHz                11
# Intel Celeron Dual Core N3050 1.6GHz      11
# Intel Pentium Quad Core N3710 1.6GHz      11
# AMD A9-Series 9420 3GHz                   11
# Intel Core i7 6820HK 2.7GHz               10
# Intel Core i3 6100U 2.3GHz                 9
# Intel Core i3 7130U 2.7GHz                 8
# AMD A6-Series 9220 2.5GHz                  7
# Intel Core i5 6300HQ 2.3GHz                7
# Intel Core i7 7820HK 2.9GHz                7
# Intel Core i7 6820HQ 2.7GHz                7
# Intel Atom x5-Z8350 1.44GHz                5
#                                         ...
# AMD Ryzen 1600 3.2GHz                      1
# Intel Core M m7-6Y75 1.2GHz                1
# AMD E-Series E2-9000 2.2GHz                1
# Intel Core i7 6920HQ 2.9GHz                1
# Intel Core i3 6006U 2.2GHz                 1
# Intel Pentium Dual Core 4405U 2.1GHz       1
# Intel Core i7 7700HQ 2.7GHz                1
# AMD FX 8800P 2.1GHz                        1
# Intel Core M 7Y30 1.0GHz                   1
# Intel Core i5 1.3GHz                       1
# Samsung Cortex A72&A53 2.0GHz              1
# Intel Core i3 6100U 2.1GHz                 1
# AMD E-Series 6110 1.5GHz                   1
# Intel Core i5 7500U 2.7GHz                 1
# Intel Core i5 2.9GHz                       1
# Intel Celeron Dual Core N3350 2.0GHz       1
# Intel Core i5 2.0GHz                       1
# Intel Celeron Quad Core N3710 1.6GHz       1
# Intel Atom Z8350 1.92GHz                   1
# Intel Core M M7-6Y75 1.2GHz                1
# Intel Core i7 2.8GHz                       1
# Intel Pentium Dual Core N4200 1.1GHz       1
# AMD E-Series 9000 2.2GHz                   1
# AMD A6-Series 9220 2.9GHz                  1
# Intel Core i5 7200U 2.50GHz                1
# AMD E-Series E2-6110 1.5GHz                1
# Intel Core M 6Y54 1.1GHz                   1
# Intel Pentium Dual Core 4405Y 1.5GHz       1
# Intel Celeron Dual Core N3060 1.60GHz      1
# Intel Core M M3-6Y30 0.9GHz                1
# Name: Cpu, Length: 118, dtype: int64

# %%
df['Cpu Name'] = df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))
df.head()
# Out:
#   Company      Product   TypeName  Inches                         Cpu   Ram  \
# 0   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 2.3GHz   8GB
# 1   Apple  Macbook Air  Ultrabook    13.3        Intel Core i5 1.8GHz   8GB
# 2      HP       250 G6   Notebook    15.6  Intel Core i5 7200U 2.5GHz   8GB
# 3   Apple  MacBook Pro  Ultrabook    15.4        Intel Core i7 2.7GHz  16GB
# 4   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros  Touchscreen  Ips  X_sr  Y_sr       Cpu Name
# 0      1339.69            0    1  2560  1600  Intel Core i5
# 1       898.94            0    0  1440   900  Intel Core i5
# 2       575.00            0    0  1920  1080  Intel Core i5
# 3      2537.45            0    1  2880  1800  Intel Core i7
# 4      1803.60            0    1  2560  1600  Intel Core i5

# %%
def cpubrand(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu brand'] = df['Cpu Name'].apply(cpubrand)
df.head()
# Out:
#   Company      Product   TypeName  Inches                         Cpu   Ram  \
# 0   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 2.3GHz   8GB
# 1   Apple  Macbook Air  Ultrabook    13.3        Intel Core i5 1.8GHz   8GB
# 2      HP       250 G6   Notebook    15.6  Intel Core i5 7200U 2.5GHz   8GB
# 3   Apple  MacBook Pro  Ultrabook    15.4        Intel Core i7 2.7GHz  16GB
# 4   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros  Touchscreen  Ips  X_sr  Y_sr       Cpu Name      Cpu brand
# 0      1339.69            0    1  2560  1600  Intel Core i5  Intel Core i5
# 1       898.94            0    0  1440   900  Intel Core i5  Intel Core i5
# 2       575.00            0    0  1920  1080  Intel Core i5  Intel Core i5
# 3      2537.45            0    1  2880  1800  Intel Core i7  Intel Core i7
# 4      1803.60            0    1  2560  1600  Intel Core i5  Intel Core i5

# %%
df['Cpu brand'].value_counts().plot(kind='bar')

# %%
sns.barplot(x=df['Cpu brand'],y=df['Price_euros'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop('Cpu',axis =1,inplace = True)

# %%
df.drop('Cpu Name',axis =1,inplace = True)

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches   Ram               Memory  \
# 0   Apple  MacBook Pro  Ultrabook    13.3   8GB            128GB SSD
# 1   Apple  Macbook Air  Ultrabook    13.3   8GB  128GB Flash Storage
# 2      HP       250 G6   Notebook    15.6   8GB            256GB SSD
# 3   Apple  MacBook Pro  Ultrabook    15.4  16GB            512GB SSD
# 4   Apple  MacBook Pro  Ultrabook    13.3   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69            0    1
# 1        Intel HD Graphics 6000  macOS  1.34kg       898.94            0    0
# 2         Intel HD Graphics 620  No OS  1.86kg       575.00            0    0
# 3            AMD Radeon Pro 455  macOS  1.83kg      2537.45            0    1
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg      1803.60            0    1
#
#    X_sr  Y_sr      Cpu brand
# 0  2560  1600  Intel Core i5
# 1  1440   900  Intel Core i5
# 2  1920  1080  Intel Core i5
# 3  2880  1800  Intel Core i7
# 4  2560  1600  Intel Core i5

# %%
df['Ram'] = df['Ram'].str.replace('GB','')
df['Ram'] = df['Ram'].astype('int32')

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches  Ram               Memory  \
# 0   Apple  MacBook Pro  Ultrabook    13.3    8            128GB SSD
# 1   Apple  Macbook Air  Ultrabook    13.3    8  128GB Flash Storage
# 2      HP       250 G6   Notebook    15.6    8            256GB SSD
# 3   Apple  MacBook Pro  Ultrabook    15.4   16            512GB SSD
# 4   Apple  MacBook Pro  Ultrabook    13.3    8            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69            0    1
# 1        Intel HD Graphics 6000  macOS  1.34kg       898.94            0    0
# 2         Intel HD Graphics 620  No OS  1.86kg       575.00            0    0
# 3            AMD Radeon Pro 455  macOS  1.83kg      2537.45            0    1
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg      1803.60            0    1
#
#    X_sr  Y_sr      Cpu brand
# 0  2560  1600  Intel Core i5
# 1  1440   900  Intel Core i5
# 2  1920  1080  Intel Core i5
# 3  2880  1800  Intel Core i7
# 4  2560  1600  Intel Core i5

# %%
df['Ram'].value_counts().plot(kind='bar')

# %%
sns.barplot(x=df['Ram'],y=df['Price_euros'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  256GB SSD             2
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  500GB HDD             2
# 512GB SSD +  512GB SSD             1
# 240GB SSD                          1
# 512GB SSD +  256GB SSD             1
# 1.0TB HDD                          1
# 64GB SSD                           1
# 32GB HDD                           1
# 128GB HDD                          1
# 1TB HDD +  1TB HDD                 1
# 512GB SSD +  1.0TB Hybrid          1
# 508GB Hybrid                       1
# 256GB SSD +  1.0TB Hybrid          1
# 64GB Flash Storage +  1TB HDD      1
# 8GB SSD                            1
# Name: Memory, dtype: int64

# %%
split_mem = df['Memory'].str.split(' ', 1, expand=True)
df['Storage Type'] = split_mem[1]
df['Memory'] = split_mem[0]
df["Memory"].unique()
df.head()
# Out:
#   Company      Product   TypeName  Inches  Ram Memory  \
# 0   Apple  MacBook Pro  Ultrabook    13.3    8  128GB
# 1   Apple  Macbook Air  Ultrabook    13.3    8  128GB
# 2      HP       250 G6   Notebook    15.6    8  256GB
# 3   Apple  MacBook Pro  Ultrabook    15.4   16  512GB
# 4   Apple  MacBook Pro  Ultrabook    13.3    8  256GB
#
#                             Gpu  OpSys  Weight  Price_euros  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69            0    1
# 1        Intel HD Graphics 6000  macOS  1.34kg       898.94            0    0
# 2         Intel HD Graphics 620  No OS  1.86kg       575.00            0    0
# 3            AMD Radeon Pro 455  macOS  1.83kg      2537.45            0    1
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg      1803.60            0    1
#
#    X_sr  Y_sr      Cpu brand   Storage Type
# 0  2560  1600  Intel Core i5            SSD
# 1  1440   900  Intel Core i5  Flash Storage
# 2  1920  1080  Intel Core i5            SSD
# 3  2880  1800  Intel Core i7            SSD
# 4  2560  1600  Intel Core i5            SSD

# %%
df['Memory'].value_counts().plot(kind='bar')

# %%
df['Storage Type'].value_counts().plot(kind='bar')

# %%
df['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620           281
# Intel HD Graphics 520           185
# Intel UHD Graphics 620           68
# Nvidia GeForce GTX 1050          66
# Nvidia GeForce GTX 1060          48
# Nvidia GeForce 940MX             43
# AMD Radeon 530                   41
# Intel HD Graphics 500            39
# Intel HD Graphics 400            37
# Nvidia GeForce GTX 1070          30
# Intel HD Graphics                29
# Nvidia GeForce GTX 1050 Ti       28
# AMD Radeon R5 M430               22
# Nvidia GeForce 930MX             20
# AMD Radeon 520                   17
# Nvidia GeForce MX150             15
# Intel HD Graphics 515            15
# Nvidia GeForce GTX 960M          14
# AMD Radeon R7 M445               14
# Intel HD Graphics 615            14
# Nvidia GeForce 920MX             13
# Intel HD Graphics 505            12
# AMD Radeon R5                    11
# Nvidia GeForce GTX 980M          10
# Nvidia Quadro M1200               9
# Intel HD Graphics 405             9
# AMD Radeon R5 M420                8
# Intel Iris Plus Graphics 640      8
# AMD Radeon R5 M330                7
# Nvidia GeForce GTX 950M           7
#                                ...
# AMD Radeon R7 Graphics            1
# Nvidia GTX 980 SLI                1
# Nvidia GeForce GTX 1070M          1
# Nvidia GeForce GTX 980            1
# AMD Radeon RX 560                 1
# Intel Iris Graphics 550           1
# AMD FirePro W4190M                1
# Nvidia GeForce 940M               1
# AMD Radeon R7                     1
# Nvidia GeForce GTX1050 Ti         1
# AMD Radeon 540                    1
# AMD Radeon R9 M385                1
# Nvidia GeForce GTX 930MX          1
# ARM Mali T860 MP4                 1
# AMD Radeon Pro 555                1
# Nvidia GeForce GTX1060            1
# AMD Radeon R7 M360                1
# AMD FirePro W5130M                1
# AMD Radeon R7 M365X               1
# AMD Radeon R5 430                 1
# AMD Radeon R5 M315                1
# AMD Radeon R3                     1
# Intel Graphics 620                1
# Nvidia GeForce GTX 940M           1
# Nvidia GeForce 960M               1
# Intel HD Graphics 620             1
# Nvidia GeForce GTX1080            1
# AMD Radeon R7 M465                1
# Nvidia Quadro M620M               1
# AMD Radeon Pro 455                1
# Name: Gpu, Length: 110, dtype: int64

# %%
df['Gpu brand'] = df['Gpu'].apply(lambda x:x.split()[0])

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches  Ram Memory  \
# 0   Apple  MacBook Pro  Ultrabook    13.3    8  128GB
# 1   Apple  Macbook Air  Ultrabook    13.3    8  128GB
# 2      HP       250 G6   Notebook    15.6    8  256GB
# 3   Apple  MacBook Pro  Ultrabook    15.4   16  512GB
# 4   Apple  MacBook Pro  Ultrabook    13.3    8  256GB
#
#                             Gpu  OpSys  Weight  Price_euros  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69            0    1
# 1        Intel HD Graphics 6000  macOS  1.34kg       898.94            0    0
# 2         Intel HD Graphics 620  No OS  1.86kg       575.00            0    0
# 3            AMD Radeon Pro 455  macOS  1.83kg      2537.45            0    1
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg      1803.60            0    1
#
#    X_sr  Y_sr      Cpu brand   Storage Type Gpu brand
# 0  2560  1600  Intel Core i5            SSD     Intel
# 1  1440   900  Intel Core i5  Flash Storage     Intel
# 2  1920  1080  Intel Core i5            SSD     Intel
# 3  2880  1800  Intel Core i7            SSD       AMD
# 4  2560  1600  Intel Core i5            SSD     Intel

# %%
df['Gpu brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: Gpu brand, dtype: int64

# %%
sns.barplot(x=df['Gpu brand'],y=df['Price_euros'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         27
# macOS             13
# Windows 10 S       8
# Mac OS X           8
# Android            2
# Name: OpSys, dtype: int64

# %%
sns.barplot(x=df['OpSys'],y=df['Price_euros'])
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# Replace the KG in weight and make the datatype as INT

# %%
df['Weight'] = df['Weight'].str.replace('kg','')
df['Weight'] = df['Weight'].astype('float32')

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches  Ram Memory  \
# 0   Apple  MacBook Pro  Ultrabook    13.3    8  128GB
# 1   Apple  Macbook Air  Ultrabook    13.3    8  128GB
# 2      HP       250 G6   Notebook    15.6    8  256GB
# 3   Apple  MacBook Pro  Ultrabook    15.4   16  512GB
# 4   Apple  MacBook Pro  Ultrabook    13.3    8  256GB
#
#                             Gpu  OpSys  Weight  Price_euros  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37      1339.69            0    1
# 1        Intel HD Graphics 6000  macOS    1.34       898.94            0    0
# 2         Intel HD Graphics 620  No OS    1.86       575.00            0    0
# 3            AMD Radeon Pro 455  macOS    1.83      2537.45            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37      1803.60            0    1
#
#    X_sr  Y_sr      Cpu brand   Storage Type Gpu brand
# 0  2560  1600  Intel Core i5            SSD     Intel
# 1  1440   900  Intel Core i5  Flash Storage     Intel
# 2  1920  1080  Intel Core i5            SSD     Intel
# 3  2880  1800  Intel Core i7            SSD       AMD
# 4  2560  1600  Intel Core i5            SSD     Intel

# %%
sns.distplot(df['Weight'])

# %%
df.corr()['Price_euros']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price_euros    1.000000
# Touchscreen    0.191226
# Ips            0.252208
# X_sr           0.556529
# Y_sr           0.552809
# Name: Price_euros, dtype: float64

# %%
sns.distplot(np.log(df['Price_euros']))

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches  Ram Memory  \
# 0   Apple  MacBook Pro  Ultrabook    13.3    8  128GB
# 1   Apple  Macbook Air  Ultrabook    13.3    8  128GB
# 2      HP       250 G6   Notebook    15.6    8  256GB
# 3   Apple  MacBook Pro  Ultrabook    15.4   16  512GB
# 4   Apple  MacBook Pro  Ultrabook    13.3    8  256GB
#
#                             Gpu  OpSys  Weight  Price_euros  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37      1339.69            0    1
# 1        Intel HD Graphics 6000  macOS    1.34       898.94            0    0
# 2         Intel HD Graphics 620  No OS    1.86       575.00            0    0
# 3            AMD Radeon Pro 455  macOS    1.83      2537.45            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37      1803.60            0    1
#
#    X_sr  Y_sr      Cpu brand   Storage Type Gpu brand
# 0  2560  1600  Intel Core i5            SSD     Intel
# 1  1440   900  Intel Core i5  Flash Storage     Intel
# 2  1920  1080  Intel Core i5            SSD     Intel
# 3  2880  1800  Intel Core i7            SSD       AMD
# 4  2560  1600  Intel Core i5            SSD     Intel

# %% [markdown]
# Spliting the data set into X and Y

# %%
X=df.drop('Price_euros', axis=1)
y=df['Price_euros']

# %%
X
# Out:
#      Company                                    Product            TypeName  \
# 0      Apple                                MacBook Pro           Ultrabook
# 1      Apple                                Macbook Air           Ultrabook
# 2         HP                                     250 G6            Notebook
# 3      Apple                                MacBook Pro           Ultrabook
# 4      Apple                                MacBook Pro           Ultrabook
# 5       Acer                                   Aspire 3            Notebook
# 6      Apple                                MacBook Pro           Ultrabook
# 7      Apple                                Macbook Air           Ultrabook
# 8       Asus                            ZenBook UX430UN           Ultrabook
# 9       Acer                                    Swift 3           Ultrabook
# 10        HP                                     250 G6            Notebook
# 11        HP                                     250 G6            Notebook
# 12     Apple                                MacBook Pro           Ultrabook
# 13      Dell                              Inspiron 3567            Notebook
# 14     Apple                                MacBook 12"           Ultrabook
# 15     Apple                                MacBook Pro           Ultrabook
# 16      Dell                              Inspiron 3567            Notebook
# 17     Apple                                MacBook Pro           Ultrabook
# 18    Lenovo                          IdeaPad 320-15IKB            Notebook
# 19      Dell                                     XPS 13           Ultrabook
# 20      Asus                            Vivobook E200HA             Netbook
# 21    Lenovo                         Legion Y520-15IKBN              Gaming
# 22        HP                                     255 G6            Notebook
# 23      Dell                              Inspiron 5379  2 in 1 Convertible
# 24        HP    15-BS101nv (i7-8550U/8GB/256GB/FHD/W10)           Ultrabook
# 25      Dell                              Inspiron 3567            Notebook
# 26     Apple                                MacBook Air           Ultrabook
# 27      Dell                              Inspiron 5570            Notebook
# 28      Dell                              Latitude 5590           Ultrabook
# 29        HP                                ProBook 470            Notebook
# ...      ...                                        ...                 ...
# 1273      HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1274    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
# 1275    Asus                       ZenBook UX305CA-UBM1           Ultrabook
# 1276    Dell                              Inspiron 3567            Notebook
# 1277    Acer                             Aspire ES1-531            Notebook
# 1278    Dell                              Inspiron 3552            Notebook
# 1279  Lenovo                         IdeaPad Y700-15ISK            Notebook
# 1280      HP                        Pavilion 15-AW003nv            Notebook
# 1281    Dell                              Inspiron 3567            Notebook
# 1282      HP                           Stream 11-Y000na             Netbook
# 1283    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce            Notebook
# 1284  Lenovo                             Yoga 500-14ISK  2 in 1 Convertible
# 1285  Lenovo                             Yoga 900-13ISK  2 in 1 Convertible
# 1286  Lenovo                         IdeaPad 100S-14IBR            Notebook
# 1287      HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1288    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
# 1289    Asus                       ZenBook UX305CA-UBM1           Ultrabook
# 1290    Dell                              Inspiron 3567            Notebook
# 1291    Acer                             Aspire ES1-531            Notebook
# 1292    Dell                              Inspiron 3552            Notebook
# 1293  Lenovo                         IdeaPad Y700-15ISK            Notebook
# 1294      HP                        Pavilion 15-AW003nv            Notebook
# 1295    Dell                              Inspiron 3567            Notebook
# 1296      HP                           Stream 11-Y000na             Netbook
# 1297    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce            Notebook
# 1298  Lenovo                             Yoga 500-14ISK  2 in 1 Convertible
# 1299  Lenovo                             Yoga 900-13ISK  2 in 1 Convertible
# 1300  Lenovo                         IdeaPad 100S-14IBR            Notebook
# 1301      HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#       Inches  Ram Memory                           Gpu       OpSys  Weight  \
# 0       13.3    8  128GB  Intel Iris Plus Graphics 640       macOS    1.37
# 1       13.3    8  128GB        Intel HD Graphics 6000       macOS    1.34
# 2       15.6    8  256GB         Intel HD Graphics 620       No OS    1.86
# 3       15.4   16  512GB            AMD Radeon Pro 455       macOS    1.83
# 4       13.3    8  256GB  Intel Iris Plus Graphics 650       macOS    1.37
# 5       15.6    4  500GB                 AMD Radeon R5  Windows 10    2.10
# 6       15.4   16  256GB       Intel Iris Pro Graphics    Mac OS X    2.04
# 7       13.3    8  256GB        Intel HD Graphics 6000       macOS    1.34
# 8       14.0   16  512GB          Nvidia GeForce MX150  Windows 10    1.30
# 9       14.0    8  256GB        Intel UHD Graphics 620  Windows 10    1.60
# 10      15.6    4  500GB         Intel HD Graphics 620       No OS    1.86
# 11      15.6    4  500GB         Intel HD Graphics 520       No OS    1.86
# 12      15.4   16  256GB            AMD Radeon Pro 555       macOS    1.83
# 13      15.6    4  256GB            AMD Radeon R5 M430  Windows 10    2.20
# 14      12.0    8  256GB         Intel HD Graphics 615       macOS    0.92
# 15      13.3    8  256GB  Intel Iris Plus Graphics 640       macOS    1.37
# 16      15.6    8  256GB            AMD Radeon R5 M430  Windows 10    2.20
# 17      15.4   16  512GB            AMD Radeon Pro 560       macOS    1.83
# 18      15.6    8    1TB          Nvidia GeForce 940MX       No OS    2.20
# 19      13.3    8  128GB        Intel UHD Graphics 620  Windows 10    1.22
# 20      11.6    2   32GB         Intel HD Graphics 400  Windows 10    0.98
# 21      15.6    8  128GB       Nvidia GeForce GTX 1050  Windows 10    2.50
# 22      15.6    4  500GB                 AMD Radeon R2       No OS    1.86
# 23      13.3    8  256GB        Intel UHD Graphics 620  Windows 10    1.62
# 24      15.6    8  256GB         Intel HD Graphics 620  Windows 10    1.91
# 25      15.6    4    1TB         Intel HD Graphics 520  Windows 10    2.30
# 26      13.3    8  128GB        Intel HD Graphics 6000    Mac OS X    1.35
# 27      15.6    8  256GB                AMD Radeon 530  Windows 10    2.20
# 28      15.6    8  256GB        Intel UHD Graphics 620  Windows 10    1.88
# 29      17.3    8    1TB          Nvidia GeForce 930MX  Windows 10    2.50
# ...      ...  ...    ...                           ...         ...     ...
# 1273    15.6    6    1TB            AMD Radeon R5 M330  Windows 10    2.19
# 1274    15.6    4  500GB             Intel HD Graphics  Windows 10    2.20
# 1275    13.3    8  512GB         Intel HD Graphics 515  Windows 10    1.20
# 1276    15.6    6    1TB         Intel HD Graphics 620  Windows 10    2.30
# 1277    15.6    4  500GB         Intel HD Graphics 400       Linux    2.40
# 1278    15.6    2  500GB             Intel HD Graphics  Windows 10    2.20
# 1279    15.6    8    1TB       Nvidia GeForce GTX 960M  Windows 10    2.60
# 1280    15.6    6  1.0TB            AMD Radeon R7 M440  Windows 10    2.04
# 1281    15.6    8    1TB            AMD Radeon R5 M430       Linux    2.30
# 1282    11.6    2   32GB         Intel HD Graphics 400  Windows 10    1.17
# 1283    15.6    4  500GB           Nvidia GeForce 920M  Windows 10    2.20
# 1284    14.0    4  128GB         Intel HD Graphics 520  Windows 10    1.80
# 1285    13.3   16  512GB         Intel HD Graphics 520  Windows 10    1.30
# 1286    14.0    2   64GB             Intel HD Graphics  Windows 10    1.50
# 1287    15.6    6    1TB            AMD Radeon R5 M330  Windows 10    2.19
# 1288    15.6    4  500GB             Intel HD Graphics  Windows 10    2.20
# 1289    13.3    8  512GB         Intel HD Graphics 515  Windows 10    1.20
# 1290    15.6    6    1TB         Intel HD Graphics 620  Windows 10    2.30
# 1291    15.6    4  500GB         Intel HD Graphics 400       Linux    2.40
# 1292    15.6    2  500GB             Intel HD Graphics  Windows 10    2.20
# 1293    15.6    8    1TB       Nvidia GeForce GTX 960M  Windows 10    2.60
# 1294    15.6    6  1.0TB            AMD Radeon R7 M440  Windows 10    2.04
# 1295    15.6    8    1TB            AMD Radeon R5 M430       Linux    2.30
# 1296    11.6    2   32GB         Intel HD Graphics 400  Windows 10    1.17
# 1297    15.6    4  500GB           Nvidia GeForce 920M  Windows 10    2.20
# 1298    14.0    4  128GB         Intel HD Graphics 520  Windows 10    1.80
# 1299    13.3   16  512GB         Intel HD Graphics 520  Windows 10    1.30
# 1300    14.0    2   64GB             Intel HD Graphics  Windows 10    1.50
# 1301    15.6    6    1TB            AMD Radeon R5 M330  Windows 10    2.19
# 1302    15.6    4  500GB             Intel HD Graphics  Windows 10    2.20
#
#       Touchscreen  Ips  X_sr  Y_sr              Cpu brand      Storage Type  \
# 0               0    1  2560  1600          Intel Core i5               SSD
# 1               0    0  1440   900          Intel Core i5     Flash Storage
# 2               0    0  1920  1080          Intel Core i5               SSD
# 3               0    1  2880  1800          Intel Core i7               SSD
# 4               0    1  2560  1600          Intel Core i5               SSD
# 5               0    0  1366   768          AMD Processor               HDD
# 6               0    1  2880  1800          Intel Core i7     Flash Storage
# 7               0    0  1440   900          Intel Core i5     Flash Storage
# 8               0    0  1920  1080          Intel Core i7               SSD
# 9               0    1  1920  1080          Intel Core i5               SSD
# 10              0    0  1366   768          Intel Core i5               HDD
# 11              0    0  1920  1080          Intel Core i3               HDD
# 12              0    1  2880  1800          Intel Core i7               SSD
# 13              0    0  1920  1080          Intel Core i3               SSD
# 14              0    1  2304  1440  Other Intel Processor               SSD
# 15              0    1  2560  1600          Intel Core i5               SSD
# 16              0    0  1920  1080          Intel Core i7               SSD
# 17              0    1  2880  1800          Intel Core i7               SSD
# 18              0    0  1920  1080          Intel Core i3               HDD
# 19              1    1  1920  1080          Intel Core i5               SSD
# 20              0    0  1366   768  Other Intel Processor     Flash Storage
# 21              0    1  1920  1080          Intel Core i5    SSD +  1TB HDD
# 22              0    0  1366   768          AMD Processor               HDD
# 23              1    0  1920  1080          Intel Core i5               SSD
# 24              0    0  1920  1080          Intel Core i7               SSD
# 25              0    0  1366   768          Intel Core i3               HDD
# 26              0    0  1440   900          Intel Core i5     Flash Storage
# 27              0    0  1920  1080          Intel Core i5               SSD
# 28              0    0  1920  1080          Intel Core i7  SSD +  256GB SSD
# 29              0    0  1920  1080          Intel Core i5               HDD
# ...           ...  ...   ...   ...                    ...               ...
# 1273            0    0  1366   768          Intel Core i7               HDD
# 1274            0    0  1366   768  Other Intel Processor               HDD
# 1275            0    1  1920  1080  Other Intel Processor               SSD
# 1276            0    0  1366   768          Intel Core i3               HDD
# 1277            0    0  1366   768  Other Intel Processor               HDD
# 1278            0    0  1366   768  Other Intel Processor               HDD
# 1279            0    1  1920  1080          Intel Core i7               HDD
# 1280            0    0  1920  1080          AMD Processor            Hybrid
# 1281            0    0  1366   768          Intel Core i7               HDD
# 1282            0    0  1366   768  Other Intel Processor     Flash Storage
# 1283            0    0  1366   768          Intel Core i7               HDD
# 1284            1    1  1920  1080          Intel Core i7               SSD
# 1285            1    1  3200  1800          Intel Core i7               SSD
# 1286            0    0  1366   768  Other Intel Processor     Flash Storage
# 1287            0    0  1366   768          Intel Core i7               HDD
# 1288            0    0  1366   768  Other Intel Processor               HDD
# 1289            0    1  1920  1080  Other Intel Processor               SSD
# 1290            0    0  1366   768          Intel Core i3               HDD
# 1291            0    0  1366   768  Other Intel Processor               HDD
# 1292            0    0  1366   768  Other Intel Processor               HDD
# 1293            0    1  1920  1080          Intel Core i7               HDD
# 1294            0    0  1920  1080          AMD Processor            Hybrid
# 1295            0    0  1366   768          Intel Core i7               HDD
# 1296            0    0  1366   768  Other Intel Processor     Flash Storage
# 1297            0    0  1366   768          Intel Core i7               HDD
# 1298            1    1  1920  1080          Intel Core i7               SSD
# 1299            1    1  3200  1800          Intel Core i7               SSD
# 1300            0    0  1366   768  Other Intel Processor     Flash Storage
# 1301            0    0  1366   768          Intel Core i7               HDD
# 1302            0    0  1366   768  Other Intel Processor               HDD
#
#      Gpu brand
# 0        Intel
# 1        Intel
# 2        Intel
# 3          AMD
# 4        Intel
# 5          AMD
# 6        Intel
# 7        Intel
# 8       Nvidia
# 9        Intel
# 10       Intel
# 11       Intel
# 12         AMD
# 13         AMD
# 14       Intel
# 15       Intel
# 16         AMD
# 17         AMD
# 18      Nvidia
# 19       Intel
# 20       Intel
# 21      Nvidia
# 22         AMD
# 23       Intel
# 24       Intel
# 25       Intel
# 26       Intel
# 27         AMD
# 28       Intel
# 29      Nvidia
# ...        ...
# 1273       AMD
# 1274     Intel
# 1275     Intel
# 1276     Intel
# 1277     Intel
# 1278     Intel
# 1279    Nvidia
# 1280       AMD
# 1281       AMD
# 1282     Intel
# 1283    Nvidia
# 1284     Intel
# 1285     Intel
# 1286     Intel
# 1287       AMD
# 1288     Intel
# 1289     Intel
# 1290     Intel
# 1291     Intel
# 1292     Intel
# 1293    Nvidia
# 1294       AMD
# 1295       AMD
# 1296     Intel
# 1297    Nvidia
# 1298     Intel
# 1299     Intel
# 1300     Intel
# 1301       AMD
# 1302     Intel
#
# [1303 rows x 16 columns]

# %%
y
# Out:
# 0       1339.69
# 1        898.94
# 2        575.00
# 3       2537.45
# 4       1803.60
# 5        400.00
# 6       2139.97
# 7       1158.70
# 8       1495.00
# 9        770.00
# 10       393.90
# 11       344.99
# 12      2439.97
# 13       498.90
# 14      1262.40
# 15      1518.55
# 16       745.00
# 17      2858.00
# 18       499.00
# 19       979.00
# 20       191.90
# 21       999.00
# 22       258.00
# 23       819.00
# 24       659.00
# 25       418.64
# 26      1099.00
# 27       800.00
# 28      1298.00
# 29       896.00
#          ...
# 1273     764.00
# 1274     369.00
# 1275     729.00
# 1276     459.00
# 1277     289.00
# 1278     379.00
# 1279     899.00
# 1280     549.99
# 1281     805.99
# 1282     209.00
# 1283     720.32
# 1284     638.00
# 1285    1499.00
# 1286     229.00
# 1287     764.00
# 1288     369.00
# 1289     729.00
# 1290     459.00
# 1291     289.00
# 1292     379.00
# 1293     899.00
# 1294     549.99
# 1295     805.99
# 1296     209.00
# 1297     720.32
# 1298     638.00
# 1299    1499.00
# 1300     229.00
# 1301     764.00
# 1302     369.00
# Name: Price_euros, Length: 1303, dtype: float64

# %% [markdown]
# Convert categorical datas to Numeric Data

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
from sklearn.preprocessing import OneHotEncoder

# %%
# !pip install -U scikit-learn
# Out:
# Requirement already up-to-date: scikit-learn in c:\programdata\anaconda3\lib\site-packages
# Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),)': /simple/scikit-learn/
# Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),)': /simple/scikit-learn/
# Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),)': /simple/scikit-learn/
# Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),)': /simple/scikit-learn/
# Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),)': /simple/scikit-learn/
